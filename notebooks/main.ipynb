# %% [markdown]
# # Importing Dependencies

# %%
import sys
sys.path.append(r'C:\Users\gupta\OneDrive\Desktop\Projects\brain_tumor\Brain-tumor-detection')

from braintumordetection.plot import DataDF,braintumordist,CompareDist
from braintumordetection.preprocessing import preprocess_data,plot_beforeAfter
from braintumordetection.modeling.model import trainingdf,validationdf,testdf,classlabel,ModelBuilding,ModelInfoPlot

from braintumordetection.modeling.test import modeltest

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os,shutil
import cv2
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
raw = DataDF(file='interim')
braintumordist(data=raw,plot=True)

# %% [markdown]
# # Data Augmentation

# %%
from braintumordetection.augmentation import data_augmentation,list_file_dir

# %%
file = r'C:\Users\gupta\OneDrive\Desktop\Projects\brain_tumor\Brain-tumor-detection\data\raw'

# %%
data_augmentation(file_dir=file,n_generation=10)
# Out:
# path created successfully
# path created successfully
# path created successfully
# path created successfully
# path created successfully

# %% [markdown]
# ## Augmentated Data `info`

# %%
interim = DataDF(file='interim')
CompareDist(raw=raw,processed=interim)

# %% [markdown]
# # Data Preprocessing

# %%
interim_path = r'C:\Users\gupta\OneDrive\Desktop\Projects\brain_tumor\Brain-tumor-detection\data\interim'
preprocess_data(interim_path)

# %% [markdown]
# ## Before and After Processing

# %%
plot_beforeAfter(r'C:\Users\gupta\OneDrive\Desktop\Projects\brain_tumor\Brain-tumor-detection\data\interim\glioma_tumor')

# %% [markdown]
# # Model Building

# %%
classlabel(data_generator=trainingdf())
# Out:
# Found 15756 images belonging to 4 classes.
# {0: 'glioma_tumor', 1: 'meningioma_tumor', 2: 'normal', 3: 'pituitary_tumor'}

# %%
info = ModelBuilding(traindf=trainingdf(),valdf=validationdf())

# %% [markdown]
# ### Model Info

# %%
ModelInfoPlot(info=info)

# %% [markdown]
# # Model Test

# %%
x,y = modeltest(path=r'C:\Users\gupta\OneDrive\Desktop\Projects\brain_tumor\Brain-tumor-detection\models',modelname='model1.keras',test = testdf())
# Out:
# Found 3375 images belonging to 4 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x,y = modeltest(path=r'C:\Users\gupta\OneDrive\Desktop\Projects\brain_tumor\Brain-tumor-detection\models',modelname='model1,keras',test = testdf())
#
# File ~\OneDrive\Desktop\Projects\brain_tumor\Brain-tumor-detection\braintumordetection\modeling\test.py:6, in modeltest(path, modelname, test)
#       4 def modeltest(path,modelname,test):
#       5     model_path = os.path.join(path,modelname)
# ----> 6     model=load_model(model_path)
#       7     testinfo = model.predict(test)
#       8     loss,accuracy = testinfo.evalaute(test)
#
# File c:\Users\gupta\OneDrive\Desktop\Projects\brain_tumor\venvdl\Lib\site-packages\keras\src\saving\saving_api.py:206, in load_model(filepath, custom_objects, compile, safe_mode)
#     200     raise ValueError(
# ...

# %%
labels = {0: 'glioma_tumor', 1: 'meningioma_tumor', 2: 'normal', 3: 'pituitary_tumor'}

if labels.keys()==1:
    print(labels)

# %%
labels.keys()
# Out:
# dict_keys([0, 1, 2, 3])

# %%
import os
os.path.join(r'C:\Users\gupta\OneDrive\Desktop\Projects\brain_tumor\Brain-tumor-detection\data\raw\meningioma_tumor\M_2.jpg')
# Out:
# 'C:\\Users\\gupta\\OneDrive\\Desktop\\Projects\\brain_tumor\\Brain-tumor-detection\\data\\raw\\meningioma_tumor\\M_2.jpg'
